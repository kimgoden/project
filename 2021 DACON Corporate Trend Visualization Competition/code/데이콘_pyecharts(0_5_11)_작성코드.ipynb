# %%
# !pip install pyecharts==0.5.11
# Out:
# ...
#      |████████████████████████████████| 122 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 520 kB 58.9 MB/s
# ...
#   Using cached pyecharts_jupyter_installer-0.0.3-py2.py3-none-any.whl (4.7 kB)
# ...
#      |████████████████████████████████| 540 kB 71.0 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 65.6 MB/s
# ...
#      |████████████████████████████████| 44 kB 3.2 MB/s
# ...
#   Created wheel for jupyter-echarts-pypkg: filename=jupyter_echarts_pypkg-0.1.2-py3-none-any.whl size=522012 sha256=9339a0c6555ffbab419d310e487a866b36acd62c0326776952521bceb2ff1055
#   Stored in directory: /root/.cache/pip/wheels/99/e3/c7/bd39db06900ca320a2fa9e9d155d8c48b5587b7cbffe923fcb
# ...
#   Created wheel for javascripthon: filename=javascripthon-0.11-py3-none-any.whl size=526641 sha256=d3e837d833b7079e58a597724775db23cbf6c78dd6139d13a9a930c09f4662c4
#   Stored in directory: /root/.cache/pip/wheels/df/41/a1/7b310f6584fdf312da29effe4149ec6c91d5538302147b904d
# ...

# %%
# !pip install pyecharts_snapshot
# Out:
# ...
#      |████████████████████████████████| 83 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 111 kB 56.5 MB/s
# ...
#      |████████████████████████████████| 138 kB 67.6 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.8 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
# !pip install chart_studio
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 127 kB 18.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.8
#     Uninstalling urllib3-1.26.8:
#       Successfully uninstalled urllib3-1.26.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import chart_studio
chart_studio.tools.set_credentials_file(username='username', api_key='api_key')

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
from pyecharts import WordCloud

configure_plotly_browser_state()


words = ['python','jupyter','numpy','pandas','matplotlib','sklearn',
        'xgboost','lightGBM','simpy','keras','tensorflow',
         'hive','hadoop','spark']
counts = [100,90,65,95,50,60,70,70,20,70,80,80,60,60]

cloud = WordCloud(width = 600,height = 420)
cloud.add(name = 'utils',attr = words,value = counts,
          shape = "circle",word_size_range = (10,70))
cloud
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="2b74b3162589493cb923998dbff0a602" style="width:600px;height:420px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_2b74b3162589493cb923998dbff0a602 = echarts.init(document.getElementById('2b74b3162589493cb923998dbff0a602'), 'light', {renderer: 'canvas'});
#
# var option_2b74b3162589493cb923998dbff0a602 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
# ...

# %%
import pandas as pd
df_all = pd.read_csv("/content/2022_01_19.csv")
df_all
# Out:
#        Unnamed: 0  Unnamed: 0.1                 회사명  ...    경력      등록일자      직종코드
# 0               0             0                미쓰냉삼  ...    신입  21-12-16  532202.0
# 1               1             1   청송해뜨는농장 농업회사법인(주)  ...    경력  21-12-16   26301.0
# 2               2             2   옥스퍼드관 YSP 연세국제어학원  ...  관계없음  21-12-16  214106.0
# 3               3             3             (주)태양건설  ...    경력  21-12-16  140203.0
# 4               4             4                 HCN  ...  관계없음  21-12-16  415301.0
# ...           ...           ...                 ...  ...   ...       ...       ...
# 30571          99            99           (주)대웅에스앤티  ...    경력  21-12-07  623004.0
# 30572           0             0  영등포대림 지역주택조합 추진위원회  ...  관계없음  22-01-18   27200.0
# 30573           1             1            (주)엔유씨전자  ...    경력  22-01-18   28404.0
# 30574           2             2         경주시장애인종합복지관  ...  관계없음  22-01-18  306901.0
# ...

# %%
df_study = df_all['최소학력'].value_counts()

# %%
df_study
# Out:
# 학력무관        22401
# 고졸           4274
# 대졸(2~3년)     2958
# 대졸(4년)        706
# 중졸            181
# 석사             34
# 초졸이하           17
# 박사              4
# Name: 최소학력, dtype: int64

# %%
from  pyecharts import Bar

configure_plotly_browser_state()
df_study = df_all['최소학력'].value_counts()

x = df_study.index
y = df_study.values

bar = Bar(title = "최소학력분포",width = 600,height = 420)
bar.add(name = "최소학력", x_axis = x, y_axis = y, )


bar
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bfed5cde09544507a7c214b0050fdcc0" style="width:600px;height:420px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bfed5cde09544507a7c214b0050fdcc0 = echarts.init(document.getElementById('bfed5cde09544507a7c214b0050fdcc0'), 'light', {renderer: 'canvas'});
#
# var option_bfed5cde09544507a7c214b0050fdcc0 = {
#     "title": [
#         {
#             "text": "\ucd5c\uc18c\ud559\ub825\ubd84\ud3ec",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
# ...

# %%
from pyecharts import Bar, Grid

configure_plotly_browser_state()
x = [
    "가나다라마바사아자차카타파하1",
    "가나다라마바사아자차카타파하2",
    "가나다라마바사아자차카타파하3",
    "가나다라마바사아자차카타파하4",
    "가나다라마바사아자차카타파하5",
    "가나다라마바사아자차카타파하6",
    "가나다라마바사아자차카타파하7",
    "가나다라마바사아자차카타파하8",
    "가나다라마바사아자차카타파하9",
]
y = [10, 20, 30, 40, 50, 60, 70, 80, 90]

grid = Grid()
bar = Bar("利用 Grid 解决 dataZoom 与 X 轴标签重叠问题",width=2000, height=2000)
bar.add("", x, y, is_datazoom_show=True, xaxis_interval=0, xaxis_rotate=300, xy_text_size= 100)
# Add bar to the grid and adjust the grid_bottom parameter appropriately to move the bar chart up
grid.add(bar, grid_bottom="50%")
grid
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="cdb748ea2dc844f49648681942691b2a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cdb748ea2dc844f49648681942691b2a = echarts.init(document.getElementById('cdb748ea2dc844f49648681942691b2a'), 'light', {renderer: 'canvas'});
#
# var option_cdb748ea2dc844f49648681942691b2a = {
#     "title": [
#         {
#             "text": "\u5229\u7528 Grid \u89e3\u51b3 dataZoom \u4e0e X \u8f74\u6807\u7b7e\u91cd\u53e0\u95ee\u9898",
#             "left": "auto",
# ...
